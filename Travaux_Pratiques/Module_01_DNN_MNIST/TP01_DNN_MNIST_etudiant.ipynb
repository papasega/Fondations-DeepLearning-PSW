# %% [markdown]
# # TP 1 — Classification MNIST avec un DNN (Étudiant) 📝
#
# **Fondations Deep Learning | Papa Séga WADE**
#
# ---
#
# ## 🎯 Objectif
#
# Construire et entraîner un **Dense Neural Network (DNN)** pour classifier les chiffres manuscrits du dataset MNIST.
#
# > 💡 Les cellules marquées `### VOTRE CODE ICI ###` sont à compléter.

# %% [markdown]
# ## Étape 1 : Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

print("TensorFlow:", tf.__version__)

# %% [markdown]
# ## Étape 2 : Chargement et exploration
#
# Chargez le dataset MNIST avec `keras.datasets.mnist.load_data()` et affichez les 10 premiers exemples.

# %%
### VOTRE CODE ICI ###
# (X_train, y_train), (X_test, y_test) = ...

# %% [markdown]
# ## Étape 3 : Prétraitement
#
# Normalisez les pixels (0→1) et aplatissez les images en vecteurs de 784 valeurs.

# %%
### VOTRE CODE ICI ###
# Normalisation
# X_train = ...
# X_test = ...

# Flatten
# X_train_flat = ...
# X_test_flat = ...

# One-hot encoding
# y_train_cat = ...
# y_test_cat = ...

# %% [markdown]
# ## Étape 4 : Définir le modèle DNN
#
# Créez un modèle `keras.Sequential` avec au moins :
# - Une couche Dense cachée (ex: 256 neurones, `relu`)
# - Une couche de sortie (10 neurones, `softmax`)

# %%
### VOTRE CODE ICI ###
model = keras.Sequential([
    # ...
])

model.summary()

# %% [markdown]
# ## Étape 5 : Compiler et entraîner
#
# Compilez avec `optimizer='adam'`, `loss='categorical_crossentropy'`, `metrics=['accuracy']`.
# Puis entraînez 10 epochs avec un `batch_size=128`.

# %%
### VOTRE CODE ICI ###
# model.compile(...)
# history = model.fit(...)

# %% [markdown]
# ## Étape 6 : Évaluation et courbes
#
# Evaluez le modèle sur le test set et tracez les courbes d'accuracy et de loss.

# %%
### VOTRE CODE ICI ###
# test_loss, test_acc = model.evaluate(...)
# print(f"Test Accuracy: {test_acc*100:.2f}%")

# Tracez les courbes...
