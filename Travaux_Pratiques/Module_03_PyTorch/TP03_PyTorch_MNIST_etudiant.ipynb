# %% [markdown]
# # TP : Classification MNIST avec PyTorch (Étudiant)
#
# Dans ce TP, vous allez traduire le modèle DNN / CNN développé sous Keras lors des modules précédents en version **PyTorch**.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

# 1. Chargement des données MNIST avec torchvision
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,)) # Normalisation basique
])

train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

# EXERCICE 1 : Créez les DataLoaders avec un batch_size de 64
train_loader = None  # VOTRE CODE ICI (utiliser DataLoader)
test_loader = None   # VOTRE CODE ICI (utiliser DataLoader)

# %% [markdown]
# ## 2. Définition du Modèle (DNN) PyTorch
#
# Pour créer un modèle en PyTorch, on crée une classe qui hérite de `nn.Module`. On définit les couches dans le constructeur `__init__`, et l'ordre de passage dans la fonction `forward()`.

# %%
class DNN_MNIST(nn.Module):
    def __init__(self):
        super(DNN_MNIST, self).__init__()
        # EXERCICE 2 : Définissez les couches
        # 1. Couche Flatten ou définition manuelle dans le forward
        # 2. Dense (Linear) 28*28 -> 128 neurones
        # 3. Dense (Linear) 128 -> 10 neurones (classes)
        
        pass # VOTRE CODE ICI

    def forward(self, x):
        # EXERCICE 3 : Appliquez les couches et la fonction d'activation ReLU
        # N'oubliez pas le flatten : x = x.view(-1, 28*28)
        
        return x # VOTRE CODE ICI

# %% [markdown]
# ## 3. Initialisation et Boucle d'entrainement

# %%
# EXERCICE 4 : Initialisez le modèle, la fonction de perte (CrossEntropyLoss) et l'optimiseur (Adam)
model = DNN_MNIST()
criterion = None # VOTRE CODE ICI
optimizer = None # VOTRE CODE ICI (lr=0.001)

epochs = 3
print("Début de l'entraînement...")

for epoch in range(epochs):
    running_loss = 0.0
    for images, labels in train_loader: # Note : train_loader doit être défini plus haut
        
        # EXERCICE 5 : Écrivez les 5 étapes de la boucle d'entraînement !
        # 1. Forward
        # 2. Loss
        # 3. Zero Grad
        # 4. Backward
        # 5. Step
        
        pass # REMPLACEZ CE PASS PAR LES 5 ETAPES
        
        # running_loss += loss.item()
        
    # print(f"Epoch {epoch+1}/{epochs} - Loss: {running_loss/len(train_loader):.4f}")
