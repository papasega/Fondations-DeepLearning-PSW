# %% [markdown]
# # Module 0 : Introduction à Python et NumPy pour le Deep Learning
#
# Ce notebook présente les bases nécessaires pour suivre les prochains TP de Deep Learning avec Keras et PyTorch.
# Vous pouvez exécuter ce notebook directement dans Google Colab.

# %% [markdown]
# ## 1. Bases de Python (Rappels)
# Les structures de données les plus utilisées pour manipuler des hyperparamètres ou des collections sont les listes et les dictionnaires.

# %%
# Exercice : Créez un dictionnaire contenant les paramètres d'entraînement
# learning_rate = 0.001, epochs = 50, batch_size = 32

training_config = {
    # VOTRE CODE ICI
}
print("Configuration :", training_config)

# %% [markdown]
# ## 2. Introduction à NumPy
# NumPy est la bibliothèque de base pour le calcul scientifique en Python. En Deep Learning, les données (images, textes) sont représentées sous forme de **tenseurs** (tableaux multidimensionnels NumPy).

# %%
import numpy as np

# Création d'un tenseur 2D aléatoire de taille (3, 3) (ex: une petite image en niveaux de gris)
tensor = np.random.rand(3, 3)

print("Shape (Dimensions) :", tensor.shape)
print("Matrice :\n", tensor)

# %%
# Exercice : Aplatissez (flatten/reshape) la matrice de (3, 3) vers un vecteur de taille (9,)
# C'est une opération courante avant une couche Dense (réseau de neurones classique) !

# VOTRE CODE ICI
vector = None 
print("Shape du vecteur :", vector.shape if vector is not None else "Non complété")

# %% [markdown]
# ## 3. Visualisation avec Matplotlib
# La visualisation est cruciale pour afficher vos courbes d'apprentissage (Loss, Accuracy) ou visualiser vos prédictions.

# %%
import matplotlib.pyplot as plt

# Créons des données factices pour une courbe de perte (Loss)
epochs = np.arange(1, 11)
loss = np.exp(-0.3 * epochs) + np.random.normal(0, 0.05, 10)

# Exercice : Tracez la courbe de l'évolution de la "Loss" en fonction des "epochs"
# Ajoutez un titre et des labels aux axes.

# VOTRE CODE ICI
plt.show()
