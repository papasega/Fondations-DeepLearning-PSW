# %% [markdown]
# # TP 2 — Classification MNIST avec un CNN (Étudiant) 📝
#
# **Fondations Deep Learning | Papa Séga WADE**
#
# ---
#
# ## 🎯 Objectif
#
# Construire un **CNN** pour classifier MNIST, puis extraire et visualiser les **embeddings** avec t-SNE.
#
# > 💡 Complétez les sections `### VOTRE CODE ICI ###`

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model
from sklearn.manifold import TSNE

# %% [markdown]
# ## Étape 1 : Charger et préparer MNIST pour un CNN
#
# ⚠️ N'oubliez pas d'ajouter la **dimension de canal** avec `np.expand_dims(X, -1)`

# %%
### VOTRE CODE ICI ###
# (X_train, y_train), (X_test, y_test) = ...
# Normalisation + expand_dims + one-hot

# %% [markdown]
# ## Étape 2 : Construire le CNN avec une couche d'embeddings
#
# Reproduisez l'architecture suivante :
# - **Bloc 1** : Conv2D (32) + MaxPooling
# - **Bloc 2** : Conv2D (64) + MaxPooling
# - **Bloc 3** : Conv2D (128) + Flatten
# - **Dense (128)** nommée `'embeddings'`
# - **Dropout (0.5)** + **Dense (10, softmax)**

# %%
### VOTRE CODE ICI ###
# Utilisez l'API Fonctionnelle Keras (keras.Input, Model(inputs, outputs))
# inputs = keras.Input(shape=(28, 28, 1))
# ...

# %% [markdown]
# ## Étape 3 : Compiler et entraîner (10 epochs)

# %%
### VOTRE CODE ICI ###

# %% [markdown]
# ## Étape 4 : Extraire les embeddings et visualiser avec t-SNE
#
# Créez un modèle intermédiaire qui renvoie la sortie de la couche `'embeddings'`, puis appliquez t-SNE pour réduire à 2D et tracez les points colorés par classe.

# %%
### VOTRE CODE ICI ###
# embedding_model = Model(inputs=model.input, outputs=model.get_layer('embeddings').output)
# embeds = embedding_model.predict(X_test[:2000])
# tsne = TSNE(...)
# embeds_2d = tsne.fit_transform(embeds)
# plt.scatter(...)  ← colorez par label
